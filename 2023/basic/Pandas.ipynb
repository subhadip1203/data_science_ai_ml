# %% [markdown]
# Panda : Series Object => one dimentionl labled array

# %%
import pandas as pd
s1 = pd.Series([1,2,3,4,5])
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1 = pd.Series([1,2,3,4,5],index=['a','b','c','d','e']) # providing maual index , a,b,c,d ..
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
